# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import  TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity, euclidean_distances

# scientific units
#from quantities import units
import utils # all datareading and preprocessing functionality

# %%
file1 = './data/abstract_set1.txt' # pesticides
file2 = './data/abstract_set2.txt' # cancer-ish
data_selection = 'abstract_clean'
label_selection = 'text_label'

# the custom class Tokenizer can also lemmatize, and remove short words, digits and stopwords
stopwords = utils.get_stopwords(custom = {'wa', 'use', 'using', 'one', 'two', 'three', 'study'}) 

tokenizer = utils.Tokenizer(stop_words=stopwords, min_length=3)

# %%
data = utils.read_abstract_data(negatives_path=file2, 
                                positives_path=file1,  
                                text_labels = ["control", "pesticide"])
#data = utils.read_abstract_data(file1, file2)

utils.preprocess_text(data)
data.head()
# Out:
#        pmid                                              title  \
# 0  29981025  Impact of Neoadjuvant Chemotherapy on Breast C...
# 1  29984001  Expert-Performed Endotracheal Intubation-Relat...
# 2  29988545  A case report: Addison disease caused by adren...
# 3  29998100  An Unusual Morphological Presentation of Cutan...
# 4  29999256  Informing Consent: Medical Malpractice and the...
#
#                                             abstract  label text_label  \
# 0  BACKGROUND: Breast cancer subtype, as determin...      0    control
# 1  The aim of this study was to determine complic...      0    control
# 2  We report middle age man with skin hyperpigmen...      0    control
# 3  Cutaneous squamous cell carcinoma (SCC) exhibi...      0    control
# 4  Since the early 1990s, jurisdictions around th...      0    control
#
#                                          title_clean  \
# 0  impact of neoadjuvant chemotherapy on breast c...
# 1  expert-performed endotracheal intubation-relat...
# 2  a case report: addison disease caused by adren...
# 3  an unusual morphological presentation of cutan...
# 4  informing consent: medical malpractice and the...
#
#                                       abstract_clean
# 0  background: breast cancer subtype, as determin...
# 1  the aim of this study was to determine complic...
# 2  we report middle age man with skin hyperpigmen...
# 3  cutaneous squamous cell carcinoma (scc) exhibi...
# 4  since the early 1990s, jurisdictions around th...

# %%
test_set = data[['pmid', 'title', 'abstract', 'text_label', 'abstract_clean']][-10:]
test_set
# these records will serve to test the model (inspect visually)
# Out:
#           pmid                                              title  \
# 9100  39365782  Bio-efficacy of field aged novel class of long...
# 9101  39367967  Comparative transcriptional analysis between s...
# 9102  39370610  Mps1-Targeted Molecular Design of Melatonin fo...
# 9103  39381929  Metabolomic profiling of in vitro and in situ ...
# 9104  39393466  Pharmacology and molecular modeling studies of...
# 9105  39399211  Cytotoxicity induced by three commercial neoni...
# 9106  39406000  Mutations in target gene confers resistance to...
# 9107  39411656  Genome-wide association study reveals the gene...
# 9108  39411737  Serum 25 hydroxycholecalciferol in periodontit...
# 9109  39427538  Soybean isoflavones protect dopaminergic neuro...
#
#                                                abstract text_label  \
# 9100  New classes of long-lasting insecticidal nets ...  pesticide
# 9101  Aedes aegypti is an important vector of arbovi...  pesticide
# 9102  Melatonin, a multifunctional class of natural ...  pesticide
# 9103  This study was begun by establishing an in vit...  pesticide
# 9104  We conducted electrophysiological and molecula...  pesticide
# 9105  Background: Neonicotinoid insecticides are use...  pesticide
# 9106  Echinochloa phyllopogon is a noxious weed that...  pesticide
# 9107  Crop resistance to herbicides is crucial for a...  pesticide
# 9108  Background: Very few studies have examined the...  pesticide
# 9109  Atrazine (ATR) is a broad-spectrum herbicide w...  pesticide
#
#                                          abstract_clean
# 9100  new classes of long-lasting insecticidal nets ...
# 9101  aedes aegypti is an important vector of arbovi...
# 9102  melatonin, a multifunctional class of natural ...
# 9103  this study was begun by establishing an in vit...
# 9104  we conducted electrophysiological and molecula...
# 9105  background: neonicotinoid insecticides are use...
# 9106  echinochloa phyllopogon is a noxious weed that...
# 9107  crop resistance to herbicides is crucial for a...
# 9108  background: very few studies have examined the...
# 9109  atrazine (atr) is a broad-spectrum herbicide w...

# %%
train_set = data[data_selection][:-10]
train_set
# Out:
# 0       background: breast cancer subtype, as determin...
# 1       the aim of this study was to determine complic...
# 2       we report middle age man with skin hyperpigmen...
# 3       cutaneous squamous cell carcinoma (scc) exhibi...
# 4       since the early 1990s, jurisdictions around th...
#                               ...
# 9095    plants are subjects of interest due to the sec...
# 9096    the sugarcane weevil (sphenophorus levis vauri...
# 9097    chlorpyrifos (cpf) has been used worldwide, bu...
# 9098    chlorantraniliprole (chl), a favored agricultu...
# 9099    multiple stimuli-responsiveness is an attracti...
# Name: abstract_clean, Length: 9100, dtype: object

# %%
vectorizer = TfidfVectorizer(tokenizer=tokenizer, max_features=5000) # bigger vocabulary seems appropriate here

# create a data matrix from the overviews
X = vectorizer.fit_transform(train_set)
X
# Out:
# /Users/michielnoback/opt/miniconda3/envs/nlp/lib/python3.12/site-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# <9100x5000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 605968 stored elements in Compressed Sparse Row format>

# %%
feature_names = vectorizer.get_feature_names_out()

# %%
# generate a mapping from paper pubmed id -> index (in df)
#paper2idx = pd.Series(data.index, index=data['pmid'])

# %%
def sort_coo(coo_matrix):
    """Sort a dict with highest score"""
    tuples = zip(coo_matrix.col, coo_matrix.data)
    return sorted(tuples, key=lambda x: (x[1], x[0]), reverse=True)

def extract_topn_from_vector(feature_names, sorted_items, topn=10):
    """get the feature names and tf-idf score of top n items"""
    
    #use only topn items from vector
    sorted_items = sorted_items[:topn]

    score_vals = []
    feature_vals = []
    
    # word index and corresponding tf-idf score
    for idx, score in sorted_items:
        
        #keep track of feature name and its corresponding score
        score_vals.append(round(score, 3))
        feature_vals.append(feature_names[idx])

    #create a tuples of feature, score
    results= {}
    for idx in range(len(feature_vals)):
        results[feature_vals[idx]]=score_vals[idx]
    
    return results

# %%
def get_keywords(vectorizer, feature_names, doc, top_n=10):
    """Return top k keywords from a doc using TF-IDF method"""

    #generate tf-idf for the given document
    tf_idf_vector = vectorizer.transform([doc])
    
    #sort the tf-idf vectors by descending order of scores
    sorted_items=sort_coo(tf_idf_vector.tocoo())

    #extract only TOP_K_KEYWORDS
    keywords=extract_topn_from_vector(feature_names, sorted_items, top_n)
    
    return list(keywords.keys())

# %%
test_set['keywords'] = None
test_set
# Out:
#           pmid                                              title  \
# 9100  39365782  Bio-efficacy of field aged novel class of long...
# 9101  39367967  Comparative transcriptional analysis between s...
# 9102  39370610  Mps1-Targeted Molecular Design of Melatonin fo...
# 9103  39381929  Metabolomic profiling of in vitro and in situ ...
# 9104  39393466  Pharmacology and molecular modeling studies of...
# 9105  39399211  Cytotoxicity induced by three commercial neoni...
# 9106  39406000  Mutations in target gene confers resistance to...
# 9107  39411656  Genome-wide association study reveals the gene...
# 9108  39411737  Serum 25 hydroxycholecalciferol in periodontit...
# 9109  39427538  Soybean isoflavones protect dopaminergic neuro...
#
#                                                abstract text_label  \
# 9100  New classes of long-lasting insecticidal nets ...  pesticide
# 9101  Aedes aegypti is an important vector of arbovi...  pesticide
# 9102  Melatonin, a multifunctional class of natural ...  pesticide
# 9103  This study was begun by establishing an in vit...  pesticide
# 9104  We conducted electrophysiological and molecula...  pesticide
# 9105  Background: Neonicotinoid insecticides are use...  pesticide
# 9106  Echinochloa phyllopogon is a noxious weed that...  pesticide
# 9107  Crop resistance to herbicides is crucial for a...  pesticide
# 9108  Background: Very few studies have examined the...  pesticide
# 9109  Atrazine (ATR) is a broad-spectrum herbicide w...  pesticide
#
#                                          abstract_clean keywords
# 9100  new classes of long-lasting insecticidal nets ...     None
# 9101  aedes aegypti is an important vector of arbovi...     None
# 9102  melatonin, a multifunctional class of natural ...     None
# 9103  this study was begun by establishing an in vit...     None
# 9104  we conducted electrophysiological and molecula...     None
# 9105  background: neonicotinoid insecticides are use...     None
# 9106  echinochloa phyllopogon is a noxious weed that...     None
# 9107  crop resistance to herbicides is crucial for a...     None
# 9108  background: very few studies have examined the...     None
# 9109  atrazine (atr) is a broad-spectrum herbicide w...     None

# %%
#result = []
for i, doc in enumerate(test_set[data_selection]):
    #df = {}
    #df['full_text'] = doc
    keywords = get_keywords(vectorizer, feature_names, doc)
    #df['top_keywords'] = keywords
    test_set.iloc[i, 5] = ", ".join(keywords)
    #result.append(df)
    
#final = pd.DataFrame(result)
#final
test_set
test_set.to_csv('tf_idf_keyword_extraction_test.csv', sep="\t")
